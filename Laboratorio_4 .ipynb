# %%
import pandas as pd
import folium
from folium.plugins import minimap



my_map = folium.Map(location=(10.617458080173108, -85.45144507184182))
my_map = folium.Map(location=(9.999117404414635, -84.11155135789294))
my_map = folium.Map(location=(9.379905042290355, -83.69108505054047))
my_map = folium.Map(location=(10.019478544366702, -84.19733766560753))
my_map = folium.Map(location=(10.13531871416936, -85.44675504049972))
my_map = folium.Map(location=(9.97095965763453, -84.1283484597573))
my_map = folium.Map(location=(10.31918168750935, -83.92259687140594))

folium.Marker(location=[10.617458080173108, -85.45144507184182],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Marker(location=[9.999042692426872, -84.11144514784638],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Marker(location=[9.379905042290355, -83.69108505054047],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Marker(location=[10.019478544366702, -84.19733766560753],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Marker(location=[10.13531871416936, -85.44675504049972],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Marker(location=[9.97095965763453, -84.1283484597573],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Marker(location=[10.31918168750935, -83.92259687140594],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
folium.Circle(location=[10.617458080173108, -85.45144507184182],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Guanacaste").add_to(my_map)
folium.Circle(location=[9.999042692426872, -84.11144514784638],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Heredia").add_to(my_map)
folium.Circle(location=[9.379905042290355, -83.69108505054047],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Perez Zeledon").add_to(my_map)
folium.Circle(location=[10.019478544366702, -84.19733766560753],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Alajuela").add_to(my_map)
folium.Circle(location=[10.13531871416936, -85.44675504049972],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Nicoya").add_to(my_map)
folium.Circle(location=[9.97095965763453, -84.1283484597573],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Lagunilla").add_to(my_map)
folium.Circle(location=[10.31918168750935, -83.92259687140594],color="purple",weight=6,fill_color="red",fill_opacity=0.05,tooltip="Sarapiqui").add_to(my_map)



my_map
# Out:
# <ipython-input-14-99f894c4ab1d>:15: UserWarning: color argument of Icon should be one of: {'lightblue', 'darkblue', 'lightred', 'green', 'darkred', 'orange', 'lightgray', 'darkgreen', 'beige', 'pink', 'gray', 'darkpurple', 'red', 'lightgreen', 'blue', 'white', 'purple', 'black', 'cadetblue'}.
#   folium.Marker(location=[10.617458080173108, -85.45144507184182],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
# <ipython-input-14-99f894c4ab1d>:16: UserWarning: color argument of Icon should be one of: {'lightblue', 'darkblue', 'lightred', 'green', 'darkred', 'orange', 'lightgray', 'darkgreen', 'beige', 'pink', 'gray', 'darkpurple', 'red', 'lightgreen', 'blue', 'white', 'purple', 'black', 'cadetblue'}.
#   folium.Marker(location=[9.999042692426872, -84.11144514784638],popup=popuptext,icon=folium.Icon(color="Orange",icon = "ok-sign")).add_to(my_map)
# ...
